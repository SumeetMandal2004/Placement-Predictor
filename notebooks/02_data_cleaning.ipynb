# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/raw/placement_data.csv')
print(f"Shape : {df.shape}")
# Out:
# Shape : (215, 15)

# %%
df = df.drop(columns=['sl_no'])
print(df.shape)
# Out:
# (215, 14)

# %%
print(f"Duplicate rows: {df.duplicated().sum()}")
# Out:
# Duplicate rows: 0

# %%
print("Missing values per column")
print(df.isnull().sum())
# Out:
# Missing values per column
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
print(df.dtypes)
# Out:
# gender                str
# ssc_p             float64
# ssc_b                 str
# hsc_p             float64
# hsc_b                 str
# hsc_s                 str
# degree_p          float64
# degree_t              str
# workex                str
# etest_p           float64
# specialisation        str
# mba_p             float64
# status                str
# salary            float64
# dtype: object

# %%
df.to_csv('../data/processed/placement_clean.csv', index = False)
print("Clean data saved to data/processed/placement_predictor.csv")
print(f"Shape: {df.shape}")
# Out:
# Clean data saved to data/processed/placement_predictor.csv
# Shape: (215, 14)
